# %% [markdown]
# # Letter Recogition

# %% [markdown]
# ### Step 1: Importing Libraries

# %%
import numpy as np
from sklearn import preprocessing, neighbors, svm
from sklearn.model_selection import train_test_split
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# I found this dataset <a href="https://archive.ics.uci.edu/ml/datasets/Letter+Recognition">here</a><br>
# <I>(Needs naming to the columns.)</I>

# %% [markdown]
# ### Step 2: Importing data

# %%
df = pd.read_csv("./Sentdex Playlist/Datasets/letter-recognition.data")
df.head()
# Out:
#   letter  x_box_hor  y_box_vert  width  height  onpix_tot  x_bar  y_bar  \
# 0      T          2           8      3       5          1      8     13
# 1      I          5          12      3       7          2     10      5
# 2      D          4          11      6       8          6     10      6
# 3      N          7          11      6       6          3      5      9
# 4      G          2           1      3       1          1      8      6
#
#    x2_bar  y2_bar  xy_bar  x2y_bar  xy2_bar  x-ege  x_egvy  y_ege  y_egvx
# 0       0       6       6       10        8      0       8      0       8
# 1       5       4      13        3        9      2       8      4      10
# 2       2       6      10        3        7      3       7      3       9
# 3       4       6       4        4       10      6      10      2       8
# 4       6       6       6        5        9      1       7      5      10

# %%
df.describe()
# Out:
#           x_box_hor    y_box_vert         width       height     onpix_tot  \
# count  20000.000000  20000.000000  20000.000000  20000.00000  20000.000000
# mean       4.023550      7.035500      5.121850      5.37245      3.505850
# std        1.913212      3.304555      2.014573      2.26139      2.190458
# min        0.000000      0.000000      0.000000      0.00000      0.000000
# 25%        3.000000      5.000000      4.000000      4.00000      2.000000
# 50%        4.000000      7.000000      5.000000      6.00000      3.000000
# 75%        5.000000      9.000000      6.000000      7.00000      5.000000
# max       15.000000     15.000000     15.000000     15.00000     15.000000
#
#               x_bar         y_bar        x2_bar        y2_bar        xy_bar  \
# count  20000.000000  20000.000000  20000.000000  20000.000000  20000.000000
# mean       6.897600      7.500450      4.628600      5.178650      8.282050
# std        2.026035      2.325354      2.699968      2.380823      2.488475
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        6.000000      6.000000      3.000000      4.000000      7.000000
# 50%        7.000000      7.000000      4.000000      5.000000      8.000000
# 75%        8.000000      9.000000      6.000000      7.000000     10.000000
# max       15.000000     15.000000     15.000000     15.000000     15.000000
#
#            x2y_bar       xy2_bar         x-ege        x_egvy         y_ege  \
# count  20000.00000  20000.000000  20000.000000  20000.000000  20000.000000
# mean       6.45400      7.929000      3.046100      8.338850      3.691750
# std        2.63107      2.080619      2.332541      1.546722      2.567073
# min        0.00000      0.000000      0.000000      0.000000      0.000000
# 25%        5.00000      7.000000      1.000000      8.000000      2.000000
# 50%        6.00000      8.000000      3.000000      8.000000      3.000000
# 75%        8.00000      9.000000      4.000000      9.000000      5.000000
# max       15.00000     15.000000     15.000000     15.000000     15.000000
#
#             y_egvx
# count  20000.00000
# mean       7.80120
# std        1.61747
# min        0.00000
# 25%        7.00000
# 50%        8.00000
# 75%        9.00000
# max       15.00000

# %%
df.fillna(-99999, axis=1, inplace=True)

# %%
features = df.drop(columns=['letter'], axis=1)

# %% [markdown]
# ### Step 3: Data Preprocessing and Exploratory Data Analysis

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
features_scaled = scaler.fit(features)
features_scaled = scaler.transform(features)

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
features_pca = pca.fit(features_scaled)
features_pca = pca.transform(features_scaled)
print(features.shape)
print(features_pca.shape)
# Out:
# (20000, 16)
# (20000, 2)

# %%
labels = np.array([ord(letter)-52 for letter in np.array(df['letter'])])
labels
# Out:
# array([32, 21, 16, ..., 32, 31, 13])

# %%
df = pd.DataFrame(features_pca, columns=["1st component", "2nd component"])
df["letter"] = labels.astype(float)
df
# Out:
#        1st component  2nd component  letter
# 0          -2.080335      -1.721468    32.0
# 1           0.369373       2.014126    21.0
# 2           1.654350       1.754982    16.0
# 3           1.490279      -0.508879    26.0
# 4          -3.080982       2.069843    19.0
# ...              ...            ...     ...
# 19995      -2.380036       0.131238    16.0
# 19996       1.957901      -1.326366    15.0
# 19997       1.285033      -3.849971    32.0
# 19998      -2.345298       0.183457    31.0
# 19999       0.065513       2.055401    13.0
#
# [20000 rows x 3 columns]

# %%
df.plot.scatter(x='1st component', y='2nd component', c='letter', cmap='gist_rainbow', figsize=(9,9), sharex=False)
# Out:
# <AxesSubplot:xlabel='1st component', ylabel='2nd component'>

# %%
from sklearn.manifold import TSNE
tsne = TSNE(n_components=2, random_state=0)
features_embedded = tsne.fit_transform(features_scaled)
features_embedded
# Out:
# c:\Users\Shrirang\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\manifold\_t_sne.py:795: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# c:\Users\Shrirang\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\manifold\_t_sne.py:805: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# array([[ 53.523285 , -61.733315 ],
#        [-12.899641 ,  39.71882  ],
#        [  2.9689672,   7.2857   ],
#        ...,
#        [ 34.968132 ,  47.707798 ],
#        [ 22.91823  ,  -8.709021 ],
#        [-43.365044 ,  35.56854  ]], dtype=float32)

# %%
df2 = pd.DataFrame(features_embedded, columns=["Dimension 1", "Dimension 2"])
df2["letter"] = labels
df2.plot.scatter(x='Dimension 1', y='Dimension 2', c='letter', cmap='gist_rainbow', figsize=(15,9), sharex=False);

# %% [markdown]
# ### Step 4: Model Training

# %%
df = pd.read_csv("./Sentdex Playlist/Datasets/letter-recognition.data")

# %%
X = np.array(df.drop(['letter'], axis=1))
y = np.array(df['letter'])
X.shape, y.shape
# Out:
# ((20000, 16), (20000,))

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((16000, 16), (4000, 16), (16000,), (4000,))

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score
classifier1 = GaussianNB()
classifier1.fit(X_train, y_train)
Y_pred = classifier1.predict(X_test)
accuracy = accuracy_score(y_test, Y_pred) * 100
print(f"With Naive Bayes:\n{accuracy=}%")
# Out:
# With Naive Bayes:
# accuracy=65.35%

# %%
knn = neighbors.KNeighborsClassifier()
knn.fit(X_train, y_train)
accuracy = knn.score(X_test, y_test)
print(f"With K-nearest Neighbours:\n{accuracy=}")
# Out:
# With K-nearest Neighbours:
# accuracy=0.94875

# %%
nusvc = svm.NuSVC()
nusvc.fit(X_train, y_train)
accuracy = nusvc.score(X_test, y_test)
print(f"With NuSVC:\n{accuracy=}")
# Out:
# With NuSVC:
# accuracy=0.81975

# %%
svc = svm.SVC()
svc.fit(X_train, y_train)
accuracy = svc.score(X_test, y_test)
print(f"With SVC:\n{accuracy=}")
# Out:
# With SVC:
# accuracy=0.92725

# %% [markdown]
# ### Step 5: Testing

# %%
example_data = [[5,9,5,8,6,6,11,7,3,7,3,9,2,7,5,11]]
example_measures = np.array(example_data).reshape(len(example_data), -1)
prediction = knn.predict(example_measures)
print(prediction)
# Out:
# ['R']

# %%
example_data = [[6,13,2,7,4,6,7,6,3,10,7,9,5,9,5,8]]
example_measures = np.array(example_data).reshape(len(example_data), -1)
prediction = knn.predict(example_measures)
print(prediction)
# Out:
# ['O']

# %% [markdown]
# ### Step 6: Model Optimization and re-training

# %%
from sklearn.model_selection import cross_val_score
k_values = range(1, 30, 2)
accuracies = dict()
for i in k_values:
    classifier = neighbors.KNeighborsClassifier(n_neighbors=i)
    scores = cross_val_score(classifier, X_train, y_train, scoring="accuracy", cv=10)
    accuracies[i] = scores.mean()

# %%
plt.plot(k_values, accuracies.values())
plt.xlabel("k values")
plt.ylabel("Accuracy")
plt.title("k value vs accuracy")
plt.plot()
# Out:
# []

# %%
optimal_k = max(zip(accuracies.values(), accuracies.keys()))[1]
optimal_k
# Out:
# 1

# %%
print(f"Percentage accuracy score for the optimal value of k for 10 cross validation data is {accuracies[optimal_k]*100}%")
# Out:
# Percentage accuracy score for the optimal value of k for 10 cross validation data is 95.53750000000001%

# %%
classifier = neighbors.KNeighborsClassifier(n_neighbors=optimal_k)
classifier.fit(X_train, y_train)
Y_pred = classifier.predict(X_test)
accuracy = accuracy_score(y_test, Y_pred) * 100
print(f"Percentage accuracy score for the optimal value of k on testing data is {accuracy}%")
# Out:
# Percentage accuracy score for the optimal value of k on testing data is 95.825%

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, Y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            A       0.99      0.99      0.99       148
#            B       0.94      0.93      0.93       140
#            C       0.93      0.96      0.94       120
#            D       0.93      0.95      0.94       168
#            E       0.96      0.95      0.96       151
#            F       0.93      0.95      0.94       148
#            G       0.96      0.96      0.96       157
#            H       0.91      0.88      0.90       151
#            I       0.99      0.97      0.98       160
#            J       0.96      0.96      0.96       142
#            K       0.91      0.91      0.91       151
#            L       0.99      0.98      0.99       160
#            M       0.97      1.00      0.98       153
#            N       0.96      0.96      0.96       156
#            O       0.94      0.96      0.95       159
#            P       0.96      0.94      0.95       173
#            Q       0.96      0.98      0.97       161
#            R       0.92      0.90      0.91       158
#            S       0.97      0.99      0.98       151
#            T       0.98      0.97      0.97       179
#            U       0.96      0.97      0.97       152
#            V       0.96      0.96      0.96       156
#            W       0.99      0.97      0.98       159
#            X       0.97      0.95      0.96       147
#            Y       0.97      0.99      0.98       155
#            Z       0.99      0.99      0.99       145
#
#     accuracy                           0.96      4000
#    macro avg       0.96      0.96      0.96      4000
# weighted avg       0.96      0.96      0.96      4000
